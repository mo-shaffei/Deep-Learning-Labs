# %% [markdown]
# <h1 align="center">UST, Zewail City</h1>
# <h2 align="center">CIE 555 (Spring 2021)</h2>
# <h2 align="center">Lab 1: Neural Network Implementation </h2>
# <h3 align="center">Aya Elzahy</h3>

# %% [markdown]
# This notebook is based on Udacity Deep Learning Nanodegree
#
# https://github.com/udacity/deep-learning-v2-pytorch/tree/master/project-bikesharing

# %% [markdown]
# # Lab objectives

# %% [markdown]
# In this lab, you will learn how to build the basic operations of a typical neural network from scratch. Network will be trained and validated using a synthetic regression dataset that we generate as part of this exercise. Learning objectives are:
#
# *   Understand the computational model of a neuron
# *   Implement the basic operations of a typical neural network.
# *   Understand the notion of backpropagation and how it is used to train neural networks.

# %% [markdown]
# # Import statements

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_regression
import sys
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import random
random.seed(10)

# %% [markdown]
# # Synthesize data

# %% [markdown]
# In this step, we generate synthetic regression data that has 200 samples and 2 features. Our neural network model will be trained and tested using this data.
#
# To use the data in our modelling exercise, we need to scale the data to have a zero mean and unit standard deviation. Scaling the data is a typical practice in neural networks' modelling to make the learning process stable.

# %%
x_data,y_data = make_regression(n_samples=200, n_features=2)

train_features,val_features, train_targets,val_targets=train_test_split(x_data,y_data,test_size=0.2)

#Fitting the scaler to training data only to prevent data leakage
feature_scaler= StandardScaler().fit(train_features)
train_features= feature_scaler.transform(train_features)
val_features= feature_scaler.transform(val_features)

target_scaler= StandardScaler().fit(train_targets.reshape(-1, 1))
train_targets=target_scaler.transform(train_targets.reshape(-1, 1))
val_targets=target_scaler.transform(val_targets.reshape(-1, 1))

# %%
print(train_features.shape)
print(val_features.shape)
# Out:
# (160, 2)
# (40, 2)

# %% [markdown]
# # Build a neural network

# %% [markdown]
# In this task, will write the basic functions of a typical neural network. The network we use in this exercise has the following architecture:
# * Two input nodes corresponding to the 2 input features.
# * Three hidden nodes in the hidden layer. All nodes in the hidden layer use ReLU activation. 'hi' is the input to the hidden layer that is the sum of w0 multiplied by the input nodes in the forward pass step. 'ho' is the output of the hidden nodes that equals to ReLU (hi).
# * One output node corresponding to the target variable in the dataset. This node doesn't use any non-linear activations. The input to the node (oi) is the sum of ho multiplied by the weights w1. The output of the node (oo) equals the input of the node(oi).
#
#
# An illustrative diagram of the network is shown below. The diagram is labeled with suggested variable names. We recommend you stick to these variable names while writing the code to avoid confusion.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.array([1, 2])
x.reshape((1, 2))
w = np.array([[1,2,3], [4,5,6]])
c = np.dot(x, w)
c = np.transpose(c)
c.shape
# Out:
# (3,)

# %% [markdown]
#  When training the network, as you will see in the upcoming section, weights will be randomly initialized using a normal distribution. The network will be trained for a certain number of iterations that you specify as a hyperparameter. In each iteration we loop over the training samples performing forward and backward operations. Netowrk is optimized using a  batch gradient descent technique. That is, we use the average delta_weight_ih and delta_weight_h_o, calcualted using all training samples, to update the weights.
#
#  Your task is to build these basic operations that will be used later in the model training.
#
#   1. Forward pass: you'll calculate the values of hi,ho,oi,oo in the function ***forward_pass*** [Task 1] and return the hidden outputs (ho) and final outputs (oo). You'll need to implement the activation in the dunction ***relu*** [Task 2] to use it for activating the input to the hidden units.
#   2. Backpropagation: You'll implement ***backpropagation*** function [Task 3] to calculate the change in weights from input to hidden layers (delta_weights_i_h) and change in weights from hidden to output layers (delta_weights_h_o). You'll need to implement ReLU derivative in the function **relu_deriv** [Task 4] to use it in backpropagation. You'll also need to implement the mean square error loss function (***MSE***) [Task 5]

# %%
def relu (x):
    #TODO: Implement the ReLU function here [1 mark]
    return np.maximum(x, 0)
        
def relu_deriv (x):
    #TODO: Implement a function to return the derivative of the ReLU function (Choose any of the 2 intervals for the value of zero) [1 mark]
    return (np.array(x) > 0) * 1

def MSE(y, Y):
    #TODO: Implement mean square error loss function [1 mark]
    return np.sum((Y - y) ** 2) / 2

# %%
def forward_pass(X,w0,w1):
    ''' Implement the forward pass of the two-layer netowrk shown above.  [3 marks]

        Arguments
        ---------
        X: feature sample with shape (2x1)
        return the final output (oo) and hidden output(ho) as per the diagram
     '''
    ### Forward pass ###
    # TODO: Hidden layer
    
    hi = np.dot((X.reshape(-1, 2)), w0) #input to hidden layer
    ho = relu(hi) # output from hidden layer

    # TODO: Output layer 
    oi = np.dot(ho, w1) #input to final output layer
    oo = oi #output from final output layer with no activation 

    return oo, ho

# %%
def backpropagation(oo, ho, X, y, delta_weights_i_h, delta_weights_h_o):
    ''' Implement tha backward pass of the network shown above [4 marks]

        Arguments
        ---------
        oo: the final output of the network produced by the forward pass 
        ho: output the hidden layer of the network produced by produced by the forward pass function 
        X: feature sample with shape (2x1)
        y: target label
        delta_weights_i_h: change in weights from input to hidden layers
        delta_weights_h_o: change in weights from hidden to output layers

        delta_weights_i_h and delta_weights_h_o accumlate the change values due to every single example. 
        In the training part at the end of the notebook, at the end of every iteration, we use these delta values to
        update the weights(weights+=learning rate*delta_weights/number of training samples),
        so don't update the weights in this function. just return the delta values. 
    '''

    # TODO: Output error- Output layer error is the difference between desired target and actual output (target-output)
    error = y - oo

    # TODO: Weight step (hidden to output)
    delta_weights_h_o += (error*ho).reshape(3, 1)

    # TODO: Weight step (input to hidden)
    delta_weights_i_h += (error*relu_deriv(ho).reshape(3, 1)*X).T

    return delta_weights_i_h, delta_weights_h_o

# %% [markdown]
# # Training the network

# %% [markdown]
# In this step, we will use the synthetic data that we generated earlier to train and test a neural network using the 'forward_pass' and 'backpropagation' functions you wrote earlier. As mentioned previously, weights will be randomly initialized using a normal distribution and they are updated using batch gradient descent. You don't have to change anything in the following cells. PLease run the code and check how the loss function is changing in each iteration.

# %%
iterations = 400  #You can change the number of iterations for better results 
lr = 0.2         #You can change the learning rate for better results 
hidden_nodes = 3 #Don't change
output_nodes = 1 #Don't change 
input_nodes= train_features.shape[1] #Don't change
n_records = train_features.shape[0]  #Don't change


# Initialize weights
#Weights are initialized randomly from a normal distribution
w0 = np.random.normal(size= (input_nodes, hidden_nodes))  #Weights input to hidden

w1 = np.random.normal(size= (hidden_nodes, output_nodes)) #weights hidden to output

losses = {'train':[], 'validation':[]}
for i in range(iterations):

    delta_weights_i_h = np.zeros(w0.shape)
    delta_weights_h_o = np.zeros(w1.shape)
    for X, y in zip(train_features, train_targets):
        oo, ho = forward_pass(X,w0,w1)  # Implement the forward pass function below  
        delta_weights_i_h, delta_weights_h_o = backpropagation(oo, ho, X, y, delta_weights_i_h, delta_weights_h_o)

    w1 += lr*delta_weights_h_o/n_records # update hidden-to-output weights with gradient descent step
    w0 += lr*delta_weights_i_h/n_records # update input-to-hidden weights with gradient descent step

    train_loss = MSE(forward_pass(train_features,w0,w1)[0], train_targets)
    val_loss = MSE(forward_pass(val_features,w0,w1)[0], val_targets)
    print("Iteration: ", i, "...Training loss: ", round(train_loss,5), "...Validation loss: ",  round(val_loss,5))    
    losses['train'].append(train_loss)
    losses['validation'].append(val_loss)
# Out:
# Iteration:  0 ...Training loss:  58.26098 ...Validation loss:  22.95107
# Iteration:  1 ...Training loss:  47.82054 ...Validation loss:  20.09827
# Iteration:  2 ...Training loss:  42.86293 ...Validation loss:  17.90902
# Iteration:  3 ...Training loss:  39.5045 ...Validation loss:  16.49758
# Iteration:  4 ...Training loss:  37.24949 ...Validation loss:  15.52796
# Iteration:  5 ...Training loss:  35.63658 ...Validation loss:  14.83147
# Iteration:  6 ...Training loss:  34.5037 ...Validation loss:  14.43367
# Iteration:  7 ...Training loss:  33.68513 ...Validation loss:  14.1887
# Iteration:  8 ...Training loss:  33.14816 ...Validation loss:  14.02371
# Iteration:  9 ...Training loss:  32.87149 ...Validation loss:  13.90449
# Iteration:  10 ...Training loss:  32.6862 ...Validation loss:  13.85999
# Iteration:  11 ...Training loss:  32.55267 ...Validation loss:  13.83585
# Iteration:  12 ...Training loss:  32.44437 ...Validation loss:  13.81242
# Iteration:  13 ...Training loss:  32.38386 ...Validation loss:  13.80083
# Iteration:  14 ...Training loss:  32.34249 ...Validation loss:  13.7864
# Iteration:  15 ...Training loss:  32.36155 ...Validation loss:  13.78825
# Iteration:  16 ...Training loss:  32.36704 ...Validation loss:  13.78478
# Iteration:  17 ...Training loss:  32.37836 ...Validation loss:  13.78023
# Iteration:  18 ...Training loss:  32.39864 ...Validation loss:  13.77193
# Iteration:  19 ...Training loss:  32.44075 ...Validation loss:  13.79119
# Iteration:  20 ...Training loss:  32.50571 ...Validation loss:  13.81709
# Iteration:  21 ...Training loss:  32.60328 ...Validation loss:  13.852
# Iteration:  22 ...Training loss:  32.66352 ...Validation loss:  13.89047
# Iteration:  23 ...Training loss:  32.70109 ...Validation loss:  13.91582
# Iteration:  24 ...Training loss:  32.73731 ...Validation loss:  13.94052
# Iteration:  25 ...Training loss:  32.78246 ...Validation loss:  13.97344
# Iteration:  26 ...Training loss:  32.83487 ...Validation loss:  14.00917
# Iteration:  27 ...Training loss:  32.89436 ...Validation loss:  14.0466
# Iteration:  28 ...Training loss:  32.96255 ...Validation loss:  14.0874
# Iteration:  29 ...Training loss:  33.03929 ...Validation loss:  14.13027
# Iteration:  30 ...Training loss:  33.12334 ...Validation loss:  14.17679
# Iteration:  31 ...Training loss:  33.20549 ...Validation loss:  14.2246
# Iteration:  32 ...Training loss:  33.29069 ...Validation loss:  14.27473
# Iteration:  33 ...Training loss:  33.38443 ...Validation loss:  14.33137
# Iteration:  34 ...Training loss:  33.49239 ...Validation loss:  14.39453
# Iteration:  35 ...Training loss:  33.60861 ...Validation loss:  14.46177
# Iteration:  36 ...Training loss:  33.73295 ...Validation loss:  14.53312
# Iteration:  37 ...Training loss:  33.86548 ...Validation loss:  14.60859
# Iteration:  38 ...Training loss:  34.0102 ...Validation loss:  14.68817
# Iteration:  39 ...Training loss:  34.15264 ...Validation loss:  14.77251
# Iteration:  40 ...Training loss:  34.28163 ...Validation loss:  14.85094
# Iteration:  41 ...Training loss:  34.41615 ...Validation loss:  14.93336
# Iteration:  42 ...Training loss:  34.54576 ...Validation loss:  15.00937
# Iteration:  43 ...Training loss:  34.68227 ...Validation loss:  15.06912
# Iteration:  44 ...Training loss:  34.82763 ...Validation loss:  15.11493
# Iteration:  45 ...Training loss:  34.98035 ...Validation loss:  15.15452
# Iteration:  46 ...Training loss:  35.13495 ...Validation loss:  15.19558
# Iteration:  47 ...Training loss:  35.2778 ...Validation loss:  15.23901
# Iteration:  48 ...Training loss:  35.36924 ...Validation loss:  15.27187
# Iteration:  49 ...Training loss:  35.46494 ...Validation loss:  15.30671
# Iteration:  50 ...Training loss:  35.56467 ...Validation loss:  15.34293
# Iteration:  51 ...Training loss:  35.669 ...Validation loss:  15.38075
# Iteration:  52 ...Training loss:  35.7619 ...Validation loss:  15.42032
# Iteration:  53 ...Training loss:  35.83136 ...Validation loss:  15.45214
# Iteration:  54 ...Training loss:  35.90297 ...Validation loss:  15.48515
# Iteration:  55 ...Training loss:  35.97723 ...Validation loss:  15.51923
# Iteration:  56 ...Training loss:  36.02627 ...Validation loss:  15.5545
# Iteration:  57 ...Training loss:  36.05231 ...Validation loss:  15.57686
# Iteration:  58 ...Training loss:  36.07886 ...Validation loss:  15.6
# Iteration:  59 ...Training loss:  36.10938 ...Validation loss:  15.62378
# Iteration:  60 ...Training loss:  36.14119 ...Validation loss:  15.64865
# Iteration:  61 ...Training loss:  36.17424 ...Validation loss:  15.67429
# Iteration:  62 ...Training loss:  36.20828 ...Validation loss:  15.70077
# Iteration:  63 ...Training loss:  36.24318 ...Validation loss:  15.71665
# Iteration:  64 ...Training loss:  36.27932 ...Validation loss:  15.72871
# Iteration:  65 ...Training loss:  36.31672 ...Validation loss:  15.74032
# Iteration:  66 ...Training loss:  36.35539 ...Validation loss:  15.75233
# Iteration:  67 ...Training loss:  36.39536 ...Validation loss:  15.76477
# Iteration:  68 ...Training loss:  36.43664 ...Validation loss:  15.77761
# Iteration:  69 ...Training loss:  36.47926 ...Validation loss:  15.79087
# Iteration:  70 ...Training loss:  36.52323 ...Validation loss:  15.80455
# Iteration:  71 ...Training loss:  36.56859 ...Validation loss:  15.82143
# Iteration:  72 ...Training loss:  36.61534 ...Validation loss:  15.84078
# Iteration:  73 ...Training loss:  36.66349 ...Validation loss:  15.86064
# Iteration:  74 ...Training loss:  36.71309 ...Validation loss:  15.88095
# Iteration:  75 ...Training loss:  36.76418 ...Validation loss:  15.90187
# Iteration:  76 ...Training loss:  36.81671 ...Validation loss:  15.92343
# Iteration:  77 ...Training loss:  36.87069 ...Validation loss:  15.94567
# Iteration:  78 ...Training loss:  36.92624 ...Validation loss:  15.96854
# Iteration:  79 ...Training loss:  36.98295 ...Validation loss:  15.99206
# Iteration:  80 ...Training loss:  37.03949 ...Validation loss:  16.01592
# Iteration:  81 ...Training loss:  37.09749 ...Validation loss:  16.04052
# Iteration:  82 ...Training loss:  37.15219 ...Validation loss:  16.06522
# Iteration:  83 ...Training loss:  37.18466 ...Validation loss:  16.074
# Iteration:  84 ...Training loss:  37.21792 ...Validation loss:  16.08317
# Iteration:  85 ...Training loss:  37.25196 ...Validation loss:  16.09238
# Iteration:  86 ...Training loss:  37.28681 ...Validation loss:  16.10182
# Iteration:  87 ...Training loss:  37.32247 ...Validation loss:  16.11146
# Iteration:  88 ...Training loss:  37.35894 ...Validation loss:  16.12133
# Iteration:  89 ...Training loss:  37.39625 ...Validation loss:  16.13144
# Iteration:  90 ...Training loss:  37.43366 ...Validation loss:  16.1418
# Iteration:  91 ...Training loss:  37.46944 ...Validation loss:  16.15219
# Iteration:  92 ...Training loss:  37.49477 ...Validation loss:  16.16289
# Iteration:  93 ...Training loss:  37.50586 ...Validation loss:  16.17161
# Iteration:  94 ...Training loss:  37.5172 ...Validation loss:  16.18039
# Iteration:  95 ...Training loss:  37.5288 ...Validation loss:  16.18907
# Iteration:  96 ...Training loss:  37.5429 ...Validation loss:  16.19773
# Iteration:  97 ...Training loss:  37.56151 ...Validation loss:  16.2049
# Iteration:  98 ...Training loss:  37.58058 ...Validation loss:  16.21256
# Iteration:  99 ...Training loss:  37.60008 ...Validation loss:  16.22053
# Iteration:  100 ...Training loss:  37.61656 ...Validation loss:  16.22813
# Iteration:  101 ...Training loss:  37.62547 ...Validation loss:  16.23457
# Iteration:  102 ...Training loss:  37.63456 ...Validation loss:  16.24117
# Iteration:  103 ...Training loss:  37.64383 ...Validation loss:  16.24779
# Iteration:  104 ...Training loss:  37.65322 ...Validation loss:  16.25452
# Iteration:  105 ...Training loss:  37.66315 ...Validation loss:  16.26135
# Iteration:  106 ...Training loss:  37.67533 ...Validation loss:  16.26739
# Iteration:  107 ...Training loss:  37.68607 ...Validation loss:  16.27363
# Iteration:  108 ...Training loss:  37.69689 ...Validation loss:  16.28003
# Iteration:  109 ...Training loss:  37.70792 ...Validation loss:  16.2866
# Iteration:  110 ...Training loss:  37.71898 ...Validation loss:  16.29333
# Iteration:  111 ...Training loss:  37.72917 ...Validation loss:  16.3004
# Iteration:  112 ...Training loss:  37.7372 ...Validation loss:  16.30709
# Iteration:  113 ...Training loss:  37.7454 ...Validation loss:  16.31383
# Iteration:  114 ...Training loss:  37.75705 ...Validation loss:  16.32058
# Iteration:  115 ...Training loss:  37.76991 ...Validation loss:  16.32525
# Iteration:  116 ...Training loss:  37.78329 ...Validation loss:  16.33056
# Iteration:  117 ...Training loss:  37.79704 ...Validation loss:  16.33643
# Iteration:  118 ...Training loss:  37.8112 ...Validation loss:  16.34265
# Iteration:  119 ...Training loss:  37.82576 ...Validation loss:  16.34915
# Iteration:  120 ...Training loss:  37.84071 ...Validation loss:  16.35591
# Iteration:  121 ...Training loss:  37.85608 ...Validation loss:  16.36289
# Iteration:  122 ...Training loss:  37.87183 ...Validation loss:  16.37009
# Iteration:  123 ...Training loss:  37.88706 ...Validation loss:  16.37747
# Iteration:  124 ...Training loss:  37.89616 ...Validation loss:  16.38375
# Iteration:  125 ...Training loss:  37.90548 ...Validation loss:  16.39013
# Iteration:  126 ...Training loss:  37.91492 ...Validation loss:  16.39653
# Iteration:  127 ...Training loss:  37.92434 ...Validation loss:  16.40323
# Iteration:  128 ...Training loss:  37.93399 ...Validation loss:  16.40992
# Iteration:  129 ...Training loss:  37.94388 ...Validation loss:  16.41667
# Iteration:  130 ...Training loss:  37.95404 ...Validation loss:  16.42348
# Iteration:  131 ...Training loss:  37.96458 ...Validation loss:  16.43029
# Iteration:  132 ...Training loss:  37.97538 ...Validation loss:  16.43721
# Iteration:  133 ...Training loss:  37.98645 ...Validation loss:  16.44425
# Iteration:  134 ...Training loss:  37.9978 ...Validation loss:  16.45141
# Iteration:  135 ...Training loss:  38.00944 ...Validation loss:  16.45869
# Iteration:  136 ...Training loss:  38.02138 ...Validation loss:  16.46611
# Iteration:  137 ...Training loss:  38.03362 ...Validation loss:  16.47365
# Iteration:  138 ...Training loss:  38.04617 ...Validation loss:  16.48133
# Iteration:  139 ...Training loss:  38.05905 ...Validation loss:  16.48914
# Iteration:  140 ...Training loss:  38.07225 ...Validation loss:  16.49151
# Iteration:  141 ...Training loss:  38.08629 ...Validation loss:  16.49043
# Iteration:  142 ...Training loss:  38.10077 ...Validation loss:  16.48891
# Iteration:  143 ...Training loss:  38.116 ...Validation loss:  16.48749
# Iteration:  144 ...Training loss:  38.13189 ...Validation loss:  16.48568
# Iteration:  145 ...Training loss:  38.14829 ...Validation loss:  16.48403
# Iteration:  146 ...Training loss:  38.16522 ...Validation loss:  16.48247
# Iteration:  147 ...Training loss:  38.18193 ...Validation loss:  16.48051
# Iteration:  148 ...Training loss:  38.19927 ...Validation loss:  16.47873
# Iteration:  149 ...Training loss:  38.21721 ...Validation loss:  16.47708
# Iteration:  150 ...Training loss:  38.23572 ...Validation loss:  16.47551
# Iteration:  151 ...Training loss:  38.25484 ...Validation loss:  16.47401
# Iteration:  152 ...Training loss:  38.27441 ...Validation loss:  16.47255
# Iteration:  153 ...Training loss:  38.29376 ...Validation loss:  16.47118
# Iteration:  154 ...Training loss:  38.31374 ...Validation loss:  16.46985
# Iteration:  155 ...Training loss:  38.33436 ...Validation loss:  16.46852
# Iteration:  156 ...Training loss:  38.35563 ...Validation loss:  16.46721
# Iteration:  157 ...Training loss:  38.37759 ...Validation loss:  16.46591
# Iteration:  158 ...Training loss:  38.40025 ...Validation loss:  16.4646
# Iteration:  159 ...Training loss:  38.42363 ...Validation loss:  16.4633
# Iteration:  160 ...Training loss:  38.44775 ...Validation loss:  16.46199
# Iteration:  161 ...Training loss:  38.47265 ...Validation loss:  16.46068
# Iteration:  162 ...Training loss:  38.49834 ...Validation loss:  16.45937
# Iteration:  163 ...Training loss:  38.52485 ...Validation loss:  16.45805
# Iteration:  164 ...Training loss:  38.5522 ...Validation loss:  16.45672
# Iteration:  165 ...Training loss:  38.58043 ...Validation loss:  16.4554
# Iteration:  166 ...Training loss:  38.60956 ...Validation loss:  16.45407
# Iteration:  167 ...Training loss:  38.63962 ...Validation loss:  16.45273
# Iteration:  168 ...Training loss:  38.67064 ...Validation loss:  16.4514
# Iteration:  169 ...Training loss:  38.70224 ...Validation loss:  16.45006
# Iteration:  170 ...Training loss:  38.73372 ...Validation loss:  16.44878
# Iteration:  171 ...Training loss:  38.76618 ...Validation loss:  16.44752
# Iteration:  172 ...Training loss:  38.79963 ...Validation loss:  16.44626
# Iteration:  173 ...Training loss:  38.83412 ...Validation loss:  16.44501
# Iteration:  174 ...Training loss:  38.86636 ...Validation loss:  16.44376
# Iteration:  175 ...Training loss:  38.88855 ...Validation loss:  16.44303
# Iteration:  176 ...Training loss:  38.91136 ...Validation loss:  16.44235
# Iteration:  177 ...Training loss:  38.93478 ...Validation loss:  16.44157
# Iteration:  178 ...Training loss:  38.95882 ...Validation loss:  16.44078
# Iteration:  179 ...Training loss:  38.98351 ...Validation loss:  16.43996
# Iteration:  180 ...Training loss:  39.00886 ...Validation loss:  16.43913
# Iteration:  181 ...Training loss:  39.03488 ...Validation loss:  16.43828
# Iteration:  182 ...Training loss:  39.06154 ...Validation loss:  16.43742
# Iteration:  183 ...Training loss:  39.08871 ...Validation loss:  16.43657
# Iteration:  184 ...Training loss:  39.11295 ...Validation loss:  16.43572
# Iteration:  185 ...Training loss:  39.13324 ...Validation loss:  16.43513
# Iteration:  186 ...Training loss:  39.15366 ...Validation loss:  16.43457
# Iteration:  187 ...Training loss:  39.17452 ...Validation loss:  16.43398
# Iteration:  188 ...Training loss:  39.19501 ...Validation loss:  16.43341
# Iteration:  189 ...Training loss:  39.21525 ...Validation loss:  16.43286
# Iteration:  190 ...Training loss:  39.23593 ...Validation loss:  16.43232
# Iteration:  191 ...Training loss:  39.2519 ...Validation loss:  16.43177
# Iteration:  192 ...Training loss:  39.2567 ...Validation loss:  16.43189
# Iteration:  193 ...Training loss:  39.2614 ...Validation loss:  16.43206
# Iteration:  194 ...Training loss:  39.2663 ...Validation loss:  16.43208
# Iteration:  195 ...Training loss:  39.27231 ...Validation loss:  16.43195
# Iteration:  196 ...Training loss:  39.27836 ...Validation loss:  16.43178
# Iteration:  197 ...Training loss:  39.28438 ...Validation loss:  16.43161
# Iteration:  198 ...Training loss:  39.28984 ...Validation loss:  16.43145
# Iteration:  199 ...Training loss:  39.29539 ...Validation loss:  16.43129
# Iteration:  200 ...Training loss:  39.30102 ...Validation loss:  16.43112
# Iteration:  201 ...Training loss:  39.30655 ...Validation loss:  16.43094
# Iteration:  202 ...Training loss:  39.31194 ...Validation loss:  16.43078
# Iteration:  203 ...Training loss:  39.31741 ...Validation loss:  16.43062
# Iteration:  204 ...Training loss:  39.32294 ...Validation loss:  16.43046
# Iteration:  205 ...Training loss:  39.32932 ...Validation loss:  16.43029
# Iteration:  206 ...Training loss:  39.337 ...Validation loss:  16.42982
# Iteration:  207 ...Training loss:  39.34486 ...Validation loss:  16.42939
# Iteration:  208 ...Training loss:  39.3529 ...Validation loss:  16.429
# Iteration:  209 ...Training loss:  39.35982 ...Validation loss:  16.42863
# Iteration:  210 ...Training loss:  39.3648 ...Validation loss:  16.42842
# Iteration:  211 ...Training loss:  39.36823 ...Validation loss:  16.42834
# Iteration:  212 ...Training loss:  39.37063 ...Validation loss:  16.42826
# Iteration:  213 ...Training loss:  39.37203 ...Validation loss:  16.42832
# Iteration:  214 ...Training loss:  39.37367 ...Validation loss:  16.42831
# Iteration:  215 ...Training loss:  39.37533 ...Validation loss:  16.42828
# Iteration:  216 ...Training loss:  39.37702 ...Validation loss:  16.42824
# Iteration:  217 ...Training loss:  39.37874 ...Validation loss:  16.42818
# Iteration:  218 ...Training loss:  39.38049 ...Validation loss:  16.42813
# Iteration:  219 ...Training loss:  39.38226 ...Validation loss:  16.42805
# Iteration:  220 ...Training loss:  39.38406 ...Validation loss:  16.42797
# Iteration:  221 ...Training loss:  39.38588 ...Validation loss:  16.42788
# Iteration:  222 ...Training loss:  39.38773 ...Validation loss:  16.42779
# Iteration:  223 ...Training loss:  39.3896 ...Validation loss:  16.42769
# Iteration:  224 ...Training loss:  39.39151 ...Validation loss:  16.4276
# Iteration:  225 ...Training loss:  39.39344 ...Validation loss:  16.4275
# Iteration:  226 ...Training loss:  39.3954 ...Validation loss:  16.4274
# Iteration:  227 ...Training loss:  39.39739 ...Validation loss:  16.4273
# Iteration:  228 ...Training loss:  39.3994 ...Validation loss:  16.42719
# Iteration:  229 ...Training loss:  39.40145 ...Validation loss:  16.42709
# Iteration:  230 ...Training loss:  39.4035 ...Validation loss:  16.42699
# Iteration:  231 ...Training loss:  39.40555 ...Validation loss:  16.42689
# Iteration:  232 ...Training loss:  39.40763 ...Validation loss:  16.4268
# Iteration:  233 ...Training loss:  39.40974 ...Validation loss:  16.4267
# Iteration:  234 ...Training loss:  39.41188 ...Validation loss:  16.4266
# Iteration:  235 ...Training loss:  39.41406 ...Validation loss:  16.4265
# Iteration:  236 ...Training loss:  39.41627 ...Validation loss:  16.42639
# Iteration:  237 ...Training loss:  39.41851 ...Validation loss:  16.42629
# Iteration:  238 ...Training loss:  39.42078 ...Validation loss:  16.42619
# Iteration:  239 ...Training loss:  39.42309 ...Validation loss:  16.42608
# Iteration:  240 ...Training loss:  39.42544 ...Validation loss:  16.42597
# Iteration:  241 ...Training loss:  39.42782 ...Validation loss:  16.42587
# Iteration:  242 ...Training loss:  39.43024 ...Validation loss:  16.42576
# Iteration:  243 ...Training loss:  39.43269 ...Validation loss:  16.42566
# Iteration:  244 ...Training loss:  39.43518 ...Validation loss:  16.42555
# Iteration:  245 ...Training loss:  39.43771 ...Validation loss:  16.42544
# Iteration:  246 ...Training loss:  39.44028 ...Validation loss:  16.42533
# Iteration:  247 ...Training loss:  39.44288 ...Validation loss:  16.42523
# Iteration:  248 ...Training loss:  39.44553 ...Validation loss:  16.42512
# Iteration:  249 ...Training loss:  39.44822 ...Validation loss:  16.42501
# Iteration:  250 ...Training loss:  39.45094 ...Validation loss:  16.4249
# Iteration:  251 ...Training loss:  39.45371 ...Validation loss:  16.42479
# Iteration:  252 ...Training loss:  39.45676 ...Validation loss:  16.42468
# Iteration:  253 ...Training loss:  39.46009 ...Validation loss:  16.42449
# Iteration:  254 ...Training loss:  39.46329 ...Validation loss:  16.42432
# Iteration:  255 ...Training loss:  39.46654 ...Validation loss:  16.42416
# Iteration:  256 ...Training loss:  39.46984 ...Validation loss:  16.42401
# Iteration:  257 ...Training loss:  39.47318 ...Validation loss:  16.42386
# Iteration:  258 ...Training loss:  39.47658 ...Validation loss:  16.42372
# Iteration:  259 ...Training loss:  39.48003 ...Validation loss:  16.42359
# Iteration:  260 ...Training loss:  39.48341 ...Validation loss:  16.42345
# Iteration:  261 ...Training loss:  39.48622 ...Validation loss:  16.42336
# Iteration:  262 ...Training loss:  39.48906 ...Validation loss:  16.42326
# Iteration:  263 ...Training loss:  39.49191 ...Validation loss:  16.42317
# Iteration:  264 ...Training loss:  39.49479 ...Validation loss:  16.42309
# Iteration:  265 ...Training loss:  39.4977 ...Validation loss:  16.423
# Iteration:  266 ...Training loss:  39.50062 ...Validation loss:  16.42292
# Iteration:  267 ...Training loss:  39.50331 ...Validation loss:  16.42283
# Iteration:  268 ...Training loss:  39.50519 ...Validation loss:  16.42281
# Iteration:  269 ...Training loss:  39.50708 ...Validation loss:  16.42279
# Iteration:  270 ...Training loss:  39.50898 ...Validation loss:  16.42276
# Iteration:  271 ...Training loss:  39.5109 ...Validation loss:  16.42273
# Iteration:  272 ...Training loss:  39.51278 ...Validation loss:  16.4227
# Iteration:  273 ...Training loss:  39.5146 ...Validation loss:  16.42268
# Iteration:  274 ...Training loss:  39.51644 ...Validation loss:  16.42266
# Iteration:  275 ...Training loss:  39.51829 ...Validation loss:  16.42264
# Iteration:  276 ...Training loss:  39.52016 ...Validation loss:  16.42261
# Iteration:  277 ...Training loss:  39.52204 ...Validation loss:  16.42259
# Iteration:  278 ...Training loss:  39.52393 ...Validation loss:  16.42256
# Iteration:  279 ...Training loss:  39.52584 ...Validation loss:  16.42252
# Iteration:  280 ...Training loss:  39.52776 ...Validation loss:  16.42249
# Iteration:  281 ...Training loss:  39.5297 ...Validation loss:  16.42246
# Iteration:  282 ...Training loss:  39.53165 ...Validation loss:  16.42243
# Iteration:  283 ...Training loss:  39.53362 ...Validation loss:  16.42239
# Iteration:  284 ...Training loss:  39.53559 ...Validation loss:  16.42236
# Iteration:  285 ...Training loss:  39.53824 ...Validation loss:  16.42233
# Iteration:  286 ...Training loss:  39.54148 ...Validation loss:  16.42205
# Iteration:  287 ...Training loss:  39.54439 ...Validation loss:  16.4218
# Iteration:  288 ...Training loss:  39.54579 ...Validation loss:  16.4217
# Iteration:  289 ...Training loss:  39.54721 ...Validation loss:  16.42162
# Iteration:  290 ...Training loss:  39.54865 ...Validation loss:  16.42153
# Iteration:  291 ...Training loss:  39.5501 ...Validation loss:  16.42145
# Iteration:  292 ...Training loss:  39.55156 ...Validation loss:  16.42138
# Iteration:  293 ...Training loss:  39.55305 ...Validation loss:  16.4213
# Iteration:  294 ...Training loss:  39.55454 ...Validation loss:  16.42123
# Iteration:  295 ...Training loss:  39.55605 ...Validation loss:  16.42116
# Iteration:  296 ...Training loss:  39.55758 ...Validation loss:  16.42109
# Iteration:  297 ...Training loss:  39.55912 ...Validation loss:  16.42103
# Iteration:  298 ...Training loss:  39.56068 ...Validation loss:  16.42096
# Iteration:  299 ...Training loss:  39.56225 ...Validation loss:  16.4209
# Iteration:  300 ...Training loss:  39.56384 ...Validation loss:  16.42084
# Iteration:  301 ...Training loss:  39.56541 ...Validation loss:  16.42078
# Iteration:  302 ...Training loss:  39.56685 ...Validation loss:  16.42067
# Iteration:  303 ...Training loss:  39.56831 ...Validation loss:  16.42056
# Iteration:  304 ...Training loss:  39.56979 ...Validation loss:  16.42047
# Iteration:  305 ...Training loss:  39.57129 ...Validation loss:  16.42038
# Iteration:  306 ...Training loss:  39.57281 ...Validation loss:  16.42029
# Iteration:  307 ...Training loss:  39.57435 ...Validation loss:  16.4202
# Iteration:  308 ...Training loss:  39.57591 ...Validation loss:  16.42012
# Iteration:  309 ...Training loss:  39.57749 ...Validation loss:  16.42004
# Iteration:  310 ...Training loss:  39.57909 ...Validation loss:  16.41997
# Iteration:  311 ...Training loss:  39.5807 ...Validation loss:  16.41988
# Iteration:  312 ...Training loss:  39.58234 ...Validation loss:  16.41979
# Iteration:  313 ...Training loss:  39.584 ...Validation loss:  16.4197
# Iteration:  314 ...Training loss:  39.58567 ...Validation loss:  16.41961
# Iteration:  315 ...Training loss:  39.58736 ...Validation loss:  16.41953
# Iteration:  316 ...Training loss:  39.58908 ...Validation loss:  16.41944
# Iteration:  317 ...Training loss:  39.59081 ...Validation loss:  16.41936
# Iteration:  318 ...Training loss:  39.59256 ...Validation loss:  16.41928
# Iteration:  319 ...Training loss:  39.59434 ...Validation loss:  16.41919
# Iteration:  320 ...Training loss:  39.59613 ...Validation loss:  16.41911
# Iteration:  321 ...Training loss:  39.59795 ...Validation loss:  16.41903
# Iteration:  322 ...Training loss:  39.59978 ...Validation loss:  16.41895
# Iteration:  323 ...Training loss:  39.60164 ...Validation loss:  16.41887
# Iteration:  324 ...Training loss:  39.60352 ...Validation loss:  16.41879
# Iteration:  325 ...Training loss:  39.60541 ...Validation loss:  16.41871
# Iteration:  326 ...Training loss:  39.60731 ...Validation loss:  16.41863
# Iteration:  327 ...Training loss:  39.6092 ...Validation loss:  16.41855
# Iteration:  328 ...Training loss:  39.61111 ...Validation loss:  16.41847
# Iteration:  329 ...Training loss:  39.61304 ...Validation loss:  16.4184
# Iteration:  330 ...Training loss:  39.61499 ...Validation loss:  16.41832
# Iteration:  331 ...Training loss:  39.61696 ...Validation loss:  16.41825
# Iteration:  332 ...Training loss:  39.61895 ...Validation loss:  16.41817
# Iteration:  333 ...Training loss:  39.62096 ...Validation loss:  16.4181
# Iteration:  334 ...Training loss:  39.623 ...Validation loss:  16.41802
# Iteration:  335 ...Training loss:  39.62505 ...Validation loss:  16.41795
# Iteration:  336 ...Training loss:  39.62713 ...Validation loss:  16.41788
# Iteration:  337 ...Training loss:  39.62923 ...Validation loss:  16.4178
# Iteration:  338 ...Training loss:  39.63135 ...Validation loss:  16.41773
# Iteration:  339 ...Training loss:  39.63349 ...Validation loss:  16.41766
# Iteration:  340 ...Training loss:  39.63566 ...Validation loss:  16.41758
# Iteration:  341 ...Training loss:  39.63785 ...Validation loss:  16.41751
# Iteration:  342 ...Training loss:  39.64006 ...Validation loss:  16.41744
# Iteration:  343 ...Training loss:  39.64229 ...Validation loss:  16.41737
# Iteration:  344 ...Training loss:  39.64455 ...Validation loss:  16.4173
# Iteration:  345 ...Training loss:  39.64683 ...Validation loss:  16.41723
# Iteration:  346 ...Training loss:  39.64913 ...Validation loss:  16.41716
# Iteration:  347 ...Training loss:  39.65146 ...Validation loss:  16.41709
# Iteration:  348 ...Training loss:  39.65382 ...Validation loss:  16.41702
# Iteration:  349 ...Training loss:  39.6562 ...Validation loss:  16.41695
# Iteration:  350 ...Training loss:  39.6586 ...Validation loss:  16.41688
# Iteration:  351 ...Training loss:  39.66103 ...Validation loss:  16.41681
# Iteration:  352 ...Training loss:  39.66348 ...Validation loss:  16.41674
# Iteration:  353 ...Training loss:  39.66596 ...Validation loss:  16.41668
# Iteration:  354 ...Training loss:  39.66847 ...Validation loss:  16.41661
# Iteration:  355 ...Training loss:  39.67079 ...Validation loss:  16.41654
# Iteration:  356 ...Training loss:  39.67247 ...Validation loss:  16.41651
# Iteration:  357 ...Training loss:  39.67418 ...Validation loss:  16.41648
# Iteration:  358 ...Training loss:  39.6759 ...Validation loss:  16.41645
# Iteration:  359 ...Training loss:  39.67764 ...Validation loss:  16.41641
# Iteration:  360 ...Training loss:  39.6794 ...Validation loss:  16.41637
# Iteration:  361 ...Training loss:  39.68117 ...Validation loss:  16.41633
# Iteration:  362 ...Training loss:  39.68296 ...Validation loss:  16.41629
# Iteration:  363 ...Training loss:  39.68476 ...Validation loss:  16.41625
# Iteration:  364 ...Training loss:  39.68658 ...Validation loss:  16.4162
# Iteration:  365 ...Training loss:  39.68842 ...Validation loss:  16.41616
# Iteration:  366 ...Training loss:  39.69027 ...Validation loss:  16.41611
# Iteration:  367 ...Training loss:  39.69214 ...Validation loss:  16.41607
# Iteration:  368 ...Training loss:  39.69403 ...Validation loss:  16.41602
# Iteration:  369 ...Training loss:  39.69593 ...Validation loss:  16.41597
# Iteration:  370 ...Training loss:  39.69785 ...Validation loss:  16.41592
# Iteration:  371 ...Training loss:  39.69979 ...Validation loss:  16.41588
# Iteration:  372 ...Training loss:  39.70174 ...Validation loss:  16.41583
# Iteration:  373 ...Training loss:  39.70372 ...Validation loss:  16.41578
# Iteration:  374 ...Training loss:  39.70571 ...Validation loss:  16.41573
# Iteration:  375 ...Training loss:  39.70771 ...Validation loss:  16.41569
# Iteration:  376 ...Training loss:  39.70974 ...Validation loss:  16.41564
# Iteration:  377 ...Training loss:  39.71178 ...Validation loss:  16.41559
# Iteration:  378 ...Training loss:  39.71385 ...Validation loss:  16.41554
# Iteration:  379 ...Training loss:  39.71593 ...Validation loss:  16.41549
# Iteration:  380 ...Training loss:  39.71803 ...Validation loss:  16.41545
# Iteration:  381 ...Training loss:  39.72013 ...Validation loss:  16.4154
# Iteration:  382 ...Training loss:  39.72218 ...Validation loss:  16.41532
# Iteration:  383 ...Training loss:  39.72425 ...Validation loss:  16.41523
# Iteration:  384 ...Training loss:  39.72633 ...Validation loss:  16.41515
# Iteration:  385 ...Training loss:  39.72833 ...Validation loss:  16.41506
# Iteration:  386 ...Training loss:  39.73013 ...Validation loss:  16.415
# Iteration:  387 ...Training loss:  39.73196 ...Validation loss:  16.41494
# Iteration:  388 ...Training loss:  39.73383 ...Validation loss:  16.41483
# Iteration:  389 ...Training loss:  39.7358 ...Validation loss:  16.41466
# Iteration:  390 ...Training loss:  39.73779 ...Validation loss:  16.4145
# Iteration:  391 ...Training loss:  39.7398 ...Validation loss:  16.41433
# Iteration:  392 ...Training loss:  39.74184 ...Validation loss:  16.41416
# Iteration:  393 ...Training loss:  39.74389 ...Validation loss:  16.414
# Iteration:  394 ...Training loss:  39.74597 ...Validation loss:  16.41384
# Iteration:  395 ...Training loss:  39.74808 ...Validation loss:  16.41368
# Iteration:  396 ...Training loss:  39.7502 ...Validation loss:  16.41352
# Iteration:  397 ...Training loss:  39.75235 ...Validation loss:  16.41337
# Iteration:  398 ...Training loss:  39.75448 ...Validation loss:  16.41322
# Iteration:  399 ...Training loss:  39.75439 ...Validation loss:  16.41317

# %%
plt.plot(losses['train'], label='Training loss')
plt.plot(losses['validation'], label='Validation loss')
plt.legend()
